# %% [markdown]
# <a href="https://colab.research.google.com/github/smartsw33t/smartsw33t/blob/main/NLP_NLU_NLG_course_Module_6_Hands_On.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# 1. The Factory: We are choosing a "text-generation" task.
# This initializes a model (GPT-2) that has been pre-trained on a massive
# library of internet text.
voice_box = pipeline("text-generation", model="gpt2")

# 2. The Seed: We give the robot a "Prompt" to start its thought.
# In NLG, the prompt is the 'Initial State' that guides the generation.
prompt = "In the heart of the ancient garden, there was a"

# 3. The Generation: The robot "breathes" and finishes the sentence.
# 'max_new_tokens' sets the limit for the output tokens to generate.
output = voice_box(prompt, max_new_tokens=30, num_return_sequences=1)

# 4. The Reveal
print("--- The Robot's Story ---")
print(output[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# --- The Robot's Story ---
# ...
