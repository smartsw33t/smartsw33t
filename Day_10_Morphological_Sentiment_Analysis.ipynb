# %% [markdown]
# <a href="https://colab.research.google.com/github/smartsw33t/smartsw33t/blob/main/Day_10_Morphological_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def advanced_tamil_sentiment(text):
    # 1. Define Suffix Patterns
    # Positive: Endings that imply 'did' or 'is'
    pos_suffixes = r"(ஆனது|உள்ளது|இருக்கும்|ஓம்|ஆன்)$"

    # Negative: Endings like 'villi' (did not), 'aadhu' (wont), 'illai' (no)
    neg_suffixes = r"(வில்லை|இல்லை|ஆது|மாட்டேன்|காது)$"

    words = text.split()
    score = 0

    for word in words:
        # Check for root keywords
        if "அழகு" in word or "சிறப்பு" in word or "பிடி" in word:
            # If the keyword has a negative suffix, it's a negative sentiment
            if re.search(neg_suffixes, word):
                score -= 1
            else:
                score += 1

    if score > 0: return "Positive 😊"
    elif score < 0: return "Negative ☹️"
    else: return "Neutral 😐"

# Test Cases
print("Test 1:", advanced_tamil_sentiment("படம் பிடிக்கவில்லை")) # Keyword 'pidi' + neg suffix
print("Test 2:", advanced_tamil_sentiment("இயற்கை அழகானது"))     # Keyword 'azhagu' + pos suffix
# Out:
# Test 1: Negative ☹️
# Test 2: Neutral 😐
